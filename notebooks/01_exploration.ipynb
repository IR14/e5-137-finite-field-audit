# %% [markdown]
# # DESI DR1 genesis-gradient first-pass exploration
#
# Use this notebook after running `cosmo-gradient run-first-pass`. It is intentionally light: the reproducible pipeline lives in `src/cosmo_gradient`.

# %%
from pathlib import Path
import pandas as pd

results_path = Path('../outputs/tables/first_pass_dipoles.csv')
results = pd.read_csv(results_path) if results_path.exists() else pd.DataFrame()
results
